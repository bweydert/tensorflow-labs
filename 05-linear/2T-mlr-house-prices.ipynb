# %% [markdown]
# <link rel='stylesheet' href='../assets/css/main.css'/>
#
# [<< back to main index](../README.md)
#
# # Multiple Linear Regression Lab 5 : House Prices
#
# ### Overview
# Estimate house prices using MLR
#
# ### Builds on
# None
#
# ### Run time
# approx. 20 minutes
#
# ### Notes

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

BATCH_SIZE=10

# %% [markdown]
# ## Step 1 : House data

# %%
housePrices = pd.read_csv("/data/house-prices/house-sales-full.csv")
housePrices
# Out:
#        DocumentID      Date  SalePrice  PropertyID   PropertyType       ym  \
# 0               1   9/16/14     280000     1000102      Multiplex   9/1/14
# 1               2   6/16/06    1000000     1200013  Single Family   6/1/06
# 2               3   1/29/07     745000     1200019  Single Family   1/1/07
# 3               4   2/25/08     425000     2800016  Single Family   2/1/08
# 4               5   3/29/13     240000     2800024  Single Family   3/1/13
# 5               6   3/30/09     349900     3600090      Townhouse   3/1/09
# 6               7   8/28/13     327500     3800004  Single Family   8/1/13
# 7               8   5/24/07     347000     3800009  Single Family   5/1/07
# 8               9   9/22/06     220400     6600055  Single Family   9/1/06
# 9              10   8/22/06     437500     7200080      Multiplex   8/1/06
# 10             11  10/16/14     150000     7200179  Single Family  10/1/14
# 11             12   1/14/10     300000     7400054  Single Family   1/1/10
# 12             13   6/26/08     292000     7400062  Single Family   6/1/08
# 13             14   5/21/14     299800     7400062  Single Family   5/1/14
# 14             15   6/13/13     370000     7600065      Townhouse   6/1/13
# 15             16   9/25/06     605000     7600093  Single Family   9/1/06
# 16             17    5/4/07     475000     7600136      Townhouse   5/1/07
# 17             18   2/24/07     425000     7600203  Single Family   2/1/07
# 18             19   3/26/08     357500     7600218      Townhouse   3/1/08
# 19             20   3/14/06     455000     9000210  Single Family   3/1/06
# 20             21   11/9/07     495000    10000060  Single Family  11/1/07
# 21             22    6/5/13     279500    11000040  Single Family   6/1/13
# 22             23   3/20/08     400000    11000041  Single Family   3/1/08
# 23             24  11/21/07     530500    11200070  Single Family  11/1/07
# 24             25   8/28/06     490000    11200370  Single Family   8/1/06
# 25             26   9/12/12     608000    11500050  Single Family   9/1/12
# 26             27    9/2/08     630000    11500270  Single Family   9/1/08
# 27             28   4/21/08     635000    11500510  Single Family   4/1/08
# 28             29   8/25/09     520000    11500510  Single Family   8/1/09
# 29             30  12/17/12     730000    11500890  Single Family  12/1/12
# ...           ...       ...        ...         ...            ...      ...
# 27033       27034   8/23/06     645000  9839300545  Single Family   8/1/06
# 27034       27035   4/11/07     687500  9839300755  Single Family   4/1/07
# 27035       27036   6/14/06     419950  9839300765  Single Family   6/1/06
# 27036       27037  12/20/10     437000  9839300800  Single Family  12/1/10
# 27037       27038   5/22/07     525000  9839300830  Single Family   5/1/07
# 27038       27039   7/21/10     305000  9839300875  Single Family   7/1/10
# 27039       27040  12/17/10     585000  9839300875  Single Family  12/1/10
# 27040       27041   4/17/08     590000  9839301055  Single Family   4/1/08
# 27041       27042   5/28/13     607500  9839301055  Single Family   5/1/13
# 27042       27043   2/22/07     757000  9839301170  Single Family   2/1/07
# 27043       27044   6/27/11     243500  9842300035  Single Family   6/1/11
# 27044       27045   1/26/07     397950  9842300087  Single Family   1/1/07
# 27045       27046   12/1/10     430000  9842300090  Single Family  12/1/10
# 27046       27047    3/1/07     400000  9842300100  Single Family   3/1/07
# 27047       27048   3/31/06     329950  9842300118  Single Family   3/1/06
# 27048       27049  11/15/06     450000  9842300150  Single Family  11/1/06
# 27049       27050    1/8/08     454500  9842300156  Single Family   1/1/08
# 27050       27051   4/23/09     396600  9842300330  Single Family   4/1/09
# 27051       27052   8/24/12     366000  9842300360  Single Family   8/1/12
# 27052       27053    5/2/06     470000  9842300440  Single Family   5/1/06
# 27053       27054   1/11/08     349500  9842300441  Single Family   1/1/08
# 27054       27055    3/2/06     379000  9842300550  Single Family   3/1/06
# 27055       27056    4/2/12     167500  9842300695  Single Family   4/1/12
# 27056       27057    4/8/11     325000  9842300710  Single Family   4/1/11
# 27057       27058   9/28/07    1580000  9845500010  Single Family   9/1/07
# 27058       27059  10/31/12     374000  9895000030      Townhouse  10/1/12
# 27059       27060   12/7/12     374000  9895000040      Townhouse  12/1/12
# 27060       27061    7/9/12     165000  9899200010  Single Family   7/1/12
# 27061       27062   5/26/06     315000  9900000355  Single Family   5/1/06
# 27062       27063    1/9/07     465000  9906000035  Single Family   1/1/07
#
#        zhvi_px  zhvi_idx  AdjSalePrice  NbrLivingUnits       ...         \
# 0       405100  0.930836      300805.0               2       ...
# 1       404400  0.929228     1076162.0               1       ...
# 2       425600  0.977941      761805.0               1       ...
# 3       418400  0.961397      442065.0               1       ...
# 4       351600  0.807904      297065.0               1       ...
# 5       369800  0.849724      411781.0               1       ...
# 6       374300  0.860064      380785.0               1       ...
# 7       432100  0.992877      349489.0               1       ...
# 8       414800  0.953125      231239.0               1       ...
# 9       411100  0.944623      463148.0               2       ...
# 10      407400  0.936121      160236.0               1       ...
# 11      350800  0.806066      372178.0               1       ...
# 12      403200  0.926471      315175.0               1       ...
# 13      398100  0.914752      327739.0               1       ...
# 14      366100  0.841222      439836.0               1       ...
# 15      414800  0.953125      634754.0               1       ...
# 16      432100  0.992877      478408.0               1       ...
# 17      427800  0.982996      432352.0               1       ...
# 18      415100  0.953814      374811.0               1       ...
# 19      392100  0.900965      505014.0               1       ...
# 20      428400  0.984375      502857.0               1       ...
# 21      366100  0.841222      332255.0               1       ...
# 22      415100  0.953814      419369.0               1       ...
# 23      428400  0.984375      538921.0               1       ...
# 24      411100  0.944623      518725.0               1       ...
# 25      329600  0.757353      802796.0               1       ...
# 26      394900  0.907399      694292.0               1       ...
# 27      411700  0.946002      671246.0               1       ...
# 28      352600  0.810202      641815.0               1       ...
# 29      339400  0.779871      936052.0               1       ...
# ...        ...       ...           ...             ...       ...
# 27033   411100  0.944623      682812.0               1       ...
# 27034   430900  0.990119      694361.0               1       ...
# 27035   404400  0.929228      451934.0               1       ...
# 27036   330600  0.759651      575264.0               1       ...
# 27037   432100  0.992877      528766.0               1       ...
# 27038   342800  0.787684      387211.0               1       ...
# 27039   330600  0.759651      770091.0               1       ...
# 27040   411700  0.946002      623677.0               1       ...
# 27041   360700  0.828814      732975.0               1       ...
# 27042   427800  0.982996      770094.0               1       ...
# 27043   315500  0.724954      335883.0               1       ...
# 27044   425600  0.977941      406926.0               1       ...
# 27045   330600  0.759651      566050.0               1       ...
# 27046   429600  0.987132      405214.0               1       ...
# 27047   392100  0.900965      366218.0               1       ...
# 27048   421200  0.967831      464957.0               1       ...
# 27049   421900  0.969439      468828.0               1       ...
# 27050   365000  0.838695      472878.0               1       ...
# 27051   327500  0.752528      486361.0               1       ...
# 27052   400600  0.920496      510594.0               1       ...
# 27053   421900  0.969439      360518.0               1       ...
# 27054   392100  0.900965      420660.0               1       ...
# 27055   315200  0.724265      231269.0               1       ...
# 27056   318700  0.732307      443803.0               1       ...
# 27057   433500  0.996094     1586196.0               1       ...
# 27058   332400  0.763787      489665.0               1       ...
# 27059   339400  0.779871      479566.0               1       ...
# 27060   325300  0.747472      220744.0               1       ...
# 27061   400600  0.920496      342207.0               1       ...
# 27062   425600  0.977941      475489.0               1       ...
#
#        Bathrooms  Bedrooms  BldgGrade  YrBuilt  YrRenovated  TrafficNoise  \
# 0           3.00         6          7     1991            0             0
# 1           3.75         4         10     2005            0             0
# 2           1.75         4          8     1947            0             0
# 3           3.75         5          7     1966            0             0
# 4           1.75         4          7     1948            0             0
# 5           1.50         2          8     2008            0             0
# 6           1.50         3          8     1961            0             0
# 7           1.75         4          7     1963            0             0
# 8           1.00         2          6     1930            0             3
# 9           2.00         4          6     1924            0             0
# 10          1.00         2          6     1925            0             0
# 11          1.00         3          7     1958            0             1
# 12          1.00         2          6     1925            0             1
# 13          1.00         2          6     1925            0             1
# 14          2.25         3          9     2014            0             2
# 15          2.75         3          8     1901            0             0
# 16          2.00         2          9     2007            0             0
# 17          1.50         4          7     1920            0             0
# 18          1.50         2          8     2007            0             0
# 19          1.75         3          6     1919            0             0
# 20          2.25         3          7     1909            0             0
# 21          3.00         3          6     2000            0             0
# 22          2.00         4          8     1960            0             0
# 23          2.50         3          8     1998            0             0
# 24          2.50         3          8     1998            0             0
# 25          2.50         3         10     1990            0             1
# 26          2.50         3         10     1992            0             0
# 27          2.50         4         10     1990            0             1
# 28          2.50         4         10     1990            0             1
# 29          2.50         3         10     1991            0             0
# ...          ...       ...        ...      ...          ...           ...
# 27033       2.00         2          8     1921            0             0
# 27034       1.00         3          8     1910            0             0
# 27035       1.75         2          7     1919            0             0
# 27036       2.75         3          8     1918         2010             2
# 27037       1.50         4          7     1908            0             0
# 27038       1.00         3          8     1906            0             0
# 27039       1.00         3          8     1906            0             0
# 27040       1.50         3          7     1906            0             0
# 27041       1.50         3          7     1906            0             0
# 27042       3.00         4          8     1901         1960             0
# 27043       1.00         3          7     1964            0             0
# 27044       4.00         7          7     1942         2007             0
# 27045       1.75         3          7     1955         2010             0
# 27046       1.00         2          7     1944            0             0
# 27047       1.00         2          6     1943            0             0
# 27048       2.50         5          7     1963         2007             0
# 27049       1.75         3          7     1957            0             0
# 27050       1.75         3          7     1944            0             1
# 27051       1.50         3          7     1954            0             1
# 27052       1.50         4          7     1954            0             0
# 27053       3.25         4          8     1925         1972             1
# 27054       1.00         2          7     1950            0             0
# 27055       1.00         2          6     1942            0             0
# 27056       1.75         3          7     1951            0             0
# 27057       4.50         4         11     2000            0             1
# 27058       1.75         2          9     2011            0             0
# 27059       1.75         2          9     2011            0             0
# 27060       1.00         4          6     1971            0             0
# 27061       2.00         3          7     1939            0             0
# 27062       1.50         3          7     1928            0             0
#
#        LandVal  ImpsVal  ZipCode  NewConstruction
# 0        70000   229000    98002            False
# 1       203000   590000    98166             True
# 2       183000   275000    98166            False
# 3       104000   229000    98168            False
# 4       104000   205000    98168            False
# 5       170000   207000    98144             True
# 6       165000   227000    98178            False
# 7       115000   154000    98178            False
# 8        90000    75000    98032            False
# 9       124000   116000    98055            False
# 10      133000    73000    98055            False
# 11      100000   172000    98118            False
# 12      100000   152000    98118            False
# 13      100000   152000    98118            False
# 14       91000   439000       -1            False
# 15      261000   422000    98122            False
# 16       91000   383000       -1             True
# 17      235000   373000    98122            False
# 18       91000   352000       -1             True
# 19      333000   117000    98115            False
# 20      212000   366000    98116            False
# 21      142000   189000    98001            False
# 22      139000   200000    98001            False
# 23      269000   209000    98007            False
# 24      269000   216000    98007            False
# 25      255000   480000    98052            False
# 26      269000   432000    98052            False
# 27      255000   416000    98052            False
# 28      255000   416000    98052            False
# 29      269000   514000    98052            False
# ...        ...      ...      ...              ...
# 27033   286000   430000    98122            False
# 27034   243000   576000    98122            False
# 27035   279000   248000    98122            False
# 27036   225000   525000    98122            False
# 27037   252000   326000    98122            False
# 27038   252000   440000    98122            False
# 27039   252000   440000    98122            False
# 27040   266000   322000    98122            False
# 27041   266000   322000    98122            False
# 27042   266000   831000    98122            False
# 27043   194000   200000    98126            False
# 27044   194000   445000    98136            False
# 27045   194000   281000    98126            False
# 27046   194000   116000    98126            False
# 27047   194000   110000    98126            False
# 27048   194000   352000    98126            False
# 27049   194000   259000    98126            False
# 27050   192000   264000    98126            False
# 27051   183000   209000    98126            False
# 27052   201000   286000    98126            False
# 27053   195000   403000    98126            False
# 27054   201000   172000    98126            False
# 27055   194000    45000    98126            False
# 27056   201000   172000    98126            False
# 27057   703000   951000    98040            False
# 27058   147000   269000       -1            False
# 27059   147000   269000       -1             True
# 27060    92000   130000    98055            False
# 27061   103000   212000    98166            False
# 27062   311000   268000    98103            False
#
# [27063 rows x 23 columns]

# %% [markdown]
# Wow! That's a lot of columns.  Maybe we should foucs on just a few of them.
#
# **=> Select only "SalePrice", "Bedrooms", "Bathrooms", "SqFtTotLiving", "SqFtLot" **

# %%
# TODO: select only "SalePrice", "Bedrooms", "Bathrooms", "SqFtTotLiving", "SqFtLot"
housePrices_small = housePrices[["SalePrice", "Bedrooms", "Bathrooms", "SqFtTotLiving", "SqFtLot"]]


housePrices_small = housePrices_small.dropna()
housePrices_small
# Out:
#        SalePrice  Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 0         280000         6       3.00           2400     9373
# 1        1000000         4       3.75           3764    20156
# 2         745000         4       1.75           2060    26036
# 3         425000         5       3.75           3200     8618
# 4         240000         4       1.75           1720     8620
# 5         349900         2       1.50            930     1012
# 6         327500         3       1.50           1750    34465
# 7         347000         4       1.75           1860    14659
# 8         220400         2       1.00            990     5324
# 9         437500         4       2.00           1980    10585
# 10        150000         2       1.00            840    12750
# 11        300000         3       1.00           1750     5200
# 12        292000         2       1.00            790     5240
# 13        299800         2       1.00            790     5240
# 14        370000         3       2.25           1530     1245
# 15        605000         3       2.75           2120     7320
# 16        475000         2       2.00           1130     1148
# 17        425000         4       1.50           2620     3485
# 18        357500         2       1.50           1250      924
# 19        455000         3       1.75           1500     5253
# 20        495000         3       2.25           2070     4600
# 21        279500         3       3.00           3020    27229
# 22        400000         4       2.00           2370    24034
# 23        530500         3       2.50           1530     3296
# 24        490000         3       2.50           1530     3696
# 25        608000         3       2.50           2780    13349
# 26        630000         3       2.50           2420     8186
# 27        635000         4       2.50           2280     9093
# 28        520000         4       2.50           2280     9093
# 29        730000         3       2.50           3130     8750
# ...          ...       ...        ...            ...      ...
# 27033     645000         2       2.00           1270     5500
# 27034     687500         3       1.00           1890     2496
# 27035     419950         2       1.75           1270     4400
# 27036     437000         3       2.75           3040     2880
# 27037     525000         4       1.50           1300     4080
# 27038     305000         3       1.00           1700     4400
# 27039     585000         3       1.00           1700     4400
# 27040     590000         3       1.50           1490     4400
# 27041     607500         3       1.50           1490     4400
# 27042     757000         4       3.00           3920     4400
# 27043     243500         3       1.00           1120     4166
# 27044     397950         7       4.00           2710     4135
# 27045     430000         3       1.75           1460     4170
# 27046     400000         2       1.00            720     4166
# 27047     329950         2       1.00            650     4155
# 27048     450000         5       2.50           2610     4353
# 27049     454500         3       1.75           2000     4186
# 27050     396600         3       1.75           1890     5705
# 27051     366000         3       1.50           1650     4163
# 27052     470000         4       1.50           1950     5019
# 27053     349500         4       3.25           2510     6021
# 27054     379000         2       1.00           1600     5150
# 27055     167500         2       1.00            650     4134
# 27056     325000         3       1.75           1480     5468
# 27057    1580000         4       4.50           4720    23914
# 27058     374000         2       1.75           1410     1161
# 27059     374000         2       1.75           1410     1005
# 27060     165000         4       1.00           1070    11170
# 27061     315000         3       2.00           1345     6223
# 27062     465000         3       1.50            790     4400
#
# [27063 rows x 5 columns]

# %% [markdown]
# ## Step 2: Create Features and Label Column in Dataframe
#
# We will create our "features" column, which is of type vector, and our label column, for which we can just reuse the SquareFootage column.
#
# **=> Build features with  "Bedrooms", "Bathrooms", "SqFtTotLiving", "SqFtLot" **

# %%
housePrices_small.iloc[:,1:]
# Out:
#        Bedrooms  Bathrooms  SqFtTotLiving  SqFtLot
# 0             6       3.00           2400     9373
# 1             4       3.75           3764    20156
# 2             4       1.75           2060    26036
# 3             5       3.75           3200     8618
# 4             4       1.75           1720     8620
# 5             2       1.50            930     1012
# 6             3       1.50           1750    34465
# 7             4       1.75           1860    14659
# 8             2       1.00            990     5324
# 9             4       2.00           1980    10585
# 10            2       1.00            840    12750
# 11            3       1.00           1750     5200
# 12            2       1.00            790     5240
# 13            2       1.00            790     5240
# 14            3       2.25           1530     1245
# 15            3       2.75           2120     7320
# 16            2       2.00           1130     1148
# 17            4       1.50           2620     3485
# 18            2       1.50           1250      924
# 19            3       1.75           1500     5253
# 20            3       2.25           2070     4600
# 21            3       3.00           3020    27229
# 22            4       2.00           2370    24034
# 23            3       2.50           1530     3296
# 24            3       2.50           1530     3696
# 25            3       2.50           2780    13349
# 26            3       2.50           2420     8186
# 27            4       2.50           2280     9093
# 28            4       2.50           2280     9093
# 29            3       2.50           3130     8750
# ...         ...        ...            ...      ...
# 27033         2       2.00           1270     5500
# 27034         3       1.00           1890     2496
# 27035         2       1.75           1270     4400
# 27036         3       2.75           3040     2880
# 27037         4       1.50           1300     4080
# 27038         3       1.00           1700     4400
# 27039         3       1.00           1700     4400
# 27040         3       1.50           1490     4400
# 27041         3       1.50           1490     4400
# 27042         4       3.00           3920     4400
# 27043         3       1.00           1120     4166
# 27044         7       4.00           2710     4135
# 27045         3       1.75           1460     4170
# 27046         2       1.00            720     4166
# 27047         2       1.00            650     4155
# 27048         5       2.50           2610     4353
# 27049         3       1.75           2000     4186
# 27050         3       1.75           1890     5705
# 27051         3       1.50           1650     4163
# 27052         4       1.50           1950     5019
# 27053         4       3.25           2510     6021
# 27054         2       1.00           1600     5150
# 27055         2       1.00            650     4134
# 27056         3       1.75           1480     5468
# 27057         4       4.50           4720    23914
# 27058         2       1.75           1410     1161
# 27059         2       1.75           1410     1005
# 27060         4       1.00           1070    11170
# 27061         3       2.00           1345     6223
# 27062         3       1.50            790     4400
#
# [27063 rows x 4 columns]

# %% [markdown]
# ##  Step 3: Run the Linear Regression Model

# %%
x = housePrices_small.iloc[:,1:]
y = housePrices_small.iloc[:,0]

# Split the data into training/testing sets
train_x = x[:-200]
test_x = x[-200:]

# Split the targets into training/testing sets
train_y = y[:-200]
test_y = y[-200:]

# %%
# Specify that all features have real-value data
feature_columns = []
for key in housePrices_small.iloc[:,1:].keys():
    feature_columns.append(tf.feature_column.numeric_column(key=key))
feature_columns
# Out:
# [_NumericColumn(key='Bedrooms', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='Bathrooms', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='SqFtTotLiving', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  _NumericColumn(key='SqFtLot', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
model = tf.estimator.LinearRegressor(feature_columns=feature_columns,
                                            model_dir="/tmp/lr_model")
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/lr_model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f00b8af9940>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# Define the input function

def train_input_fn(features, labels, batch_size):
    """An input function for training"""
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle, repeat, and batch the examples.
    dataset = dataset.shuffle(1000).repeat().batch(batch_size)

    # Return the dataset.
    return dataset

# Fit model.
# Train the Model.
model.train(
    input_fn=lambda:train_input_fn(train_x, train_y, BATCH_SIZE), steps=10000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/lr_model/model.ckpt-24000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 24001 into /tmp/lr_model/model.ckpt.
# INFO:tensorflow:loss = 1544650500000.0, step = 24001
# INFO:tensorflow:global_step/sec: 631.451
# INFO:tensorflow:loss = 2006621100000.0, step = 24101 (0.161 sec)
# INFO:tensorflow:global_step/sec: 1061.92
# INFO:tensorflow:loss = 1261975500000.0, step = 24201 (0.092 sec)
# INFO:tensorflow:global_step/sec: 1192.18
# INFO:tensorflow:loss = 1119486300000.0, step = 24301 (0.084 sec)
# INFO:tensorflow:global_step/sec: 
model/model.ckpt.
# INFO:tensorflow:Loss for final step: 2809441600000.0.

# %%
def eval_input_fn(features, labels, batch_size):
    """An input function for evaluation or prediction"""
    
    features=dict(features)
    inputs = features if labels is None else (features, labels)
   
    # Convert the inputs to a Dataset.
    return tf.data.Dataset.from_tensor_slices(inputs).batch(batch_size)


# Evaluate the model.
eval_result = model.evaluate(
    input_fn=lambda:eval_input_fn(test_x, test_y, BATCH_SIZE))

print('\nTest set accuracy: {average_loss:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-20-03:00:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/lr_model/model.ckpt-34000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-20-03:00:50
# INFO:tensorflow:Saving dict for global step 34000: average_loss = 246813770000.0, global_step = 34000, loss = 2468137700000.0
#
# Test set accuracy: 246813769728.000

# %% [markdown]
# **=> What is the meaning of coefficients and intercept? **

# %%
predictions = model.predict(
    input_fn=lambda:eval_input_fn(predict_x, batch_size=args.batch_size))

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_test = y[:-200]
x_test = x_[:-200]

y_pred = model.predict(x_test)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('r-squared score: %.2f' % r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-214aa5ea4916> in <module>()
#       7 # The mean squared error
#       8 print("Mean squared error: %.2f"
# ----> 9       % mean_squared_error(y_test, y_pred))
#      10 # Explained variance score: 1 is perfect prediction
#      11 print('r-squared score: %.2f' % r2_score(y_test, y_pred))
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     236     """
#     237     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 238         y_true, y_pred, multioutput)
#     239     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#     240                                weights=sample_weight)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ---> 75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     198     """
#     199
# --> 200     lengths = [_num_samples(X) for X in arrays if X is not None]
#     201     uniques = np.unique(lengths)
#     202     if len(uniques) > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     198     """
#     199
# --> 200     lengths = [_num_samples(X) for X in arrays if X is not None]
#     201     uniques = np.unique(lengths)
#     202     if len(uniques) > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _num_samples(x)
#     113         else:
#     114             raise TypeError("Expected sequence or array-like, got %s" %
# --> 115                             type(x))
#     116     if hasattr(x, 'shape'):
#     117         if len(x.shape) == 0:
#
# TypeError: Expected sequence or array-like, got <class 'generator'>

# %%
y_pred

# %%
x_test

# %% [markdown]
# **Observe the summary output**
#
# ## Step 3:  Predict some home prices
# Create a new data frame with the following data

# %%
# Make a Pandas dataframe
new_data = pd.DataFrame({'Bedrooms' : [5,3,2],
                         'Bathrooms' : [3,2,1.5],
                         'SqFtTotLiving' : [4400, 1800, 1550],
                         'SqFtLot' : [10000, 5000, 4000]
             })


predict_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": new_data.values},
      num_epochs=1,
      shuffle=False)

predictions = model.predict(input_fn=predict_input_fn)

list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-3c0ff0068051> in <module>()
#      15 predictions = model.predict(input_fn=predict_input_fn)
#      16
# ---> 17 list(predictions)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in predict(self, input_fn, predict_keys, hooks, checkpoint_path, yield_single_examples)
#     494           input_fn, model_fn_lib.ModeKeys.PREDICT)
#     495       estimator_spec = self._call_model_fn(
# --> 496           features, None, model_fn_lib.ModeKeys.PREDICT, self.config)
#     497       predictions = self._extract_keys(estimator_spec.predictions, predict_keys)
#     498       all_hooks = list(input_hooks)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#     829
#     830     logging.info('Calling model_fn.')
# --> 831     model_fn_results = self._model_fn(features=features, **kwargs)
#     832     logging.info('Done calling model_fn.')
#     833
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/canned/linear.py in _model_fn(features, labels, mode, config)
#     430           optimizer=optimizer,
#     431           partitioner=partitioner,
# --> 432           config=config)
#     433
#     434     super(LinearRegressor, self).__init__(
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/canned/linear.py in _linear_model_fn(features, labels, mode, head, feature_columns, optimizer, partitioner, config)
#     155     logit_fn = _linear_logit_fn_builder(
#     156         units=head.logits_dimension, feature_columns=feature_columns)
# --> 157     logits = logit_fn(features=features)
#     158
#     159     return head.create_estimator_spec(
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/canned/linear.py in linear_logit_fn(features)
#      96         feature_columns=feature_columns,
#      97         units=units,
# ---> 98         cols_to_vars=cols_to_vars)
#      99     bias = cols_to_vars.pop('bias')
#     100     if units > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in linear_model(features, feature_columns, units, sparse_combiner, weight_collections, trainable, cols_to_vars)
#     434             sparse_combiner=sparse_combiner,
#     435             weight_collections=weight_collections,
# --> 436             trainable=trainable)
#     437         weighted_sums.append(weighted_sum)
#     438         if cols_to_vars is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in _create_weighted_sum(column, builder, units, sparse_combiner, weight_collections, trainable, weight_var, state)
#    1884         trainable=trainable,
#    1885         weight_var=weight_var,
# -> 1886         state=state)
#    1887
#    1888
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in _create_dense_column_weighted_sum(column, builder, units, weight_collections, trainable, weight_var, state)
#    1905         builder,
#    1906         weight_collections=weight_collections,
# -> 1907         trainable=trainable)
#    1908   num_elements = column._variable_shape.num_elements()  # pylint: disable=protected-access
#    1909   batch_size = array_ops.shape(tensor)[0]
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in _get_dense_tensor(***failed resolving arguments***)
#    2295     # Feature has been already transformed. Return the intermediate
#    2296     # representation created by _transform_feature.
# -> 2297     return inputs.get(self)
#    2298
#    2299
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in get(self, key)
#    2098     column = key
#    2099     logging.debug('Transforming feature_column %s.', column)
# -> 2100     transformed = column._transform_feature(self)  # pylint: disable=protected-access
#    2101     if transformed is None:
#    2102       raise ValueError('Column {} is not supported.'.format(column.name))
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in _transform_feature(self, inputs)
#    2263
#    2264   def _transform_feature(self, inputs):
# -> 2265     input_tensor = inputs.get(self.key)
#    2266     if isinstance(input_tensor, sparse_tensor_lib.SparseTensor):
#    2267       raise ValueError(
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in get(self, key)
#    2090
#    2091     if isinstance(key, str):
# -> 2092       raise ValueError('Feature {} is not in features dictionary.'.format(key))
#    2093
#    2094     if not isinstance(key, _FeatureColumn):
#
# ValueError: Feature Bathrooms is not in features dictionary.

# %% [markdown]
# ## Step 4: Run on some prediction data
#
# Lets see the predicted output.
#
# **=>TODO: transform dataframe with new dataframe (.values) to get predictions **

# %%
predicted_prices = model.predict(test_x)
predicted_prices
